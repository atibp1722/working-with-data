# %%
import pandas as pd
import seaborn as sns

# %%
df=sns.load_dataset("datasets/planets")
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.tail()
# Out:
#        method  number  orbital_period  mass  distance  year
# 1030  Transit       1        3.941507   NaN     172.0  2006
# 1031  Transit       1        2.615864   NaN     148.0  2007
# 1032  Transit       1        3.191524   NaN     174.0  2007
# 1033  Transit       1        4.125083   NaN     293.0  2008
# 1034  Transit       1        4.187757   NaN     260.0  2008

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %% [markdown]
# # Grouping

# %%
df.count()
# Out:
# method            1035
# number            1035
# orbital_period     992
# mass               513
# distance           808
# year              1035
# dtype: int64

# %%
df['method'].value_counts()
# Out:
# method
# Radial Velocity                  553
# Transit                          397
# Imaging                           38
# Microlensing                      23
# Eclipse Timing Variations          9
# Pulsar Timing                      5
# Transit Timing Variations          4
# Orbital Brightness Modulation      3
# Astrometry                         2
# Pulsation Timing Variations        1
# Name: count, dtype: int64

# %%
df.isnull().any()
# Out:
# method            False
# number            False
# orbital_period     True
# mass               True
# distance           True
# year              False
# dtype: bool

# %%
df['method'].isnull().any()
# Out:
# False

# %%
unique_vals=df['method'].unique()
unique_vals
# Out:
# array(['Radial Velocity', 'Imaging', 'Eclipse Timing Variations',
#        'Transit', 'Astrometry', 'Transit Timing Variations',
#        'Orbital Brightness Modulation', 'Microlensing', 'Pulsar Timing',
#        'Pulsation Timing Variations'], dtype=object)

# %%
len(unique_vals)
# Out:
# 10

# %%
df['distance'].value_counts(dropna=False)
# Out:
# distance
# NaN       227
# 780.00      7
# 613.00      6
# 12.83       6
# 303.00      6
#          ...
# 99.40       1
# 18.21       1
# 37.78       1
# 20.98       1
# 293.00      1
# Name: count, Length: 553, dtype: int64

# %%
df['distance'].isnull().any()
# Out:
# True

# %%
df['distance'].isnull().sum()
# Out:
# 227

# %%
df.groupby('method')

# %%
df.groupby('method').mean()
# Out:
#                                  number  orbital_period      mass  \
# method
# Astrometry                     1.000000      631.180000       NaN
# Eclipse Timing Variations      1.666667     4751.644444  5.125000
# Imaging                        1.315789   118247.737500       NaN
# Microlensing                   1.173913     3153.571429       NaN
# Orbital Brightness Modulation  1.666667        0.709307       NaN
# Pulsar Timing                  2.200000     7343.021201       NaN
# Pulsation Timing Variations    1.000000     1170.000000       NaN
# Radial Velocity                1.721519      823.354680  2.630699
# Transit                        1.954660       21.102073  1.470000
# Transit Timing Variations      2.250000       79.783500       NaN
#
#                                   distance         year
# method
# Astrometry                       17.875000  2011.500000
# Eclipse Timing Variations       315.360000  2010.000000
# ...

# %%
df.groupby('method')['distance']

# %%
df.groupby('method')['distance'].mean()
# Out:
# method
# Astrometry                         17.875000
# Eclipse Timing Variations         315.360000
# Imaging                            67.715937
# Microlensing                     4144.000000
# Orbital Brightness Modulation    1180.000000
# Pulsar Timing                    1200.000000
# Pulsation Timing Variations              NaN
# Radial Velocity                    51.600208
# Transit                           599.298080
# Transit Timing Variations        1104.333333
# Name: distance, dtype: float64

# %%
df.groupby('method')['distance'].median()
# Out:
# method
# Astrometry                         17.875
# Eclipse Timing Variations         315.360
# Imaging                            40.395
# Microlensing                     3840.000
# Orbital Brightness Modulation    1180.000
# Pulsar Timing                    1200.000
# Pulsation Timing Variations           NaN
# Radial Velocity                    40.445
# Transit                           341.000
# Transit Timing Variations         855.000
# Name: distance, dtype: float64

# %%
df.groupby('year')['number']

# %%
df.groupby('year')['number'].sum()
# Out:
# year
# 1989      1
# 1992      6
# 1994      3
# 1995      1
# 1996     15
# 1997      1
# 1998     11
# 1999     24
# 2000     27
# 2001     15
# 2002     46
# 2003     35
# 2004     41
# 2005     64
# 2006     43
# 2007     65
# 2008    120
# 2009    131
# 2010    193
# 2011    354
# 2012    258
# 2013    277
# 2014    117
# Name: number, dtype: int64

# %%
df[df['year']==2001]
# Out:
#               method  number  orbital_period   mass  distance  year
# 14   Radial Velocity       3       2391.0000   0.54     14.08  2001
# 198  Radial Velocity       2        349.7000   1.25     25.64  2001
# 209  Radial Velocity       1        829.0000   0.80     32.70  2001
# 211  Radial Velocity       1        431.8800   2.07     77.82  2001
# 272  Radial Velocity       1        738.4590   2.61     34.60  2001
# 281  Radial Velocity       1        385.9000   5.59     39.56  2001
# 299  Radial Velocity       1       2063.8180  10.35     18.21  2001
# 351  Radial Velocity       1          6.2760   1.90     58.82  2001
# 371  Radial Velocity       1        111.4357    NaN     29.04  2001
# 442  Radial Velocity       1        493.7000   1.10     20.43  2001
# 540  Radial Velocity       1         71.4840   7.03     46.73  2001
# 593  Radial Velocity       1        951.0000   4.50     40.75  2001

# %%
df.groupby('method')['year'].describe()
# Out:
#                                count         mean       std     min      25%  \
# method
# Astrometry                       2.0  2011.500000  2.121320  2010.0  2010.75
# Eclipse Timing Variations        9.0  2010.000000  1.414214  2008.0  2009.00
# Imaging                         38.0  2009.131579  2.781901  2004.0  2008.00
# Microlensing                    23.0  2009.782609  2.859697  2004.0  2008.00
# Orbital Brightness Modulation    3.0  2011.666667  1.154701  2011.0  2011.00
# Pulsar Timing                    5.0  1998.400000  8.384510  1992.0  1992.00
# Pulsation Timing Variations      1.0  2007.000000       NaN  2007.0  2007.00
# Radial Velocity                553.0  2007.518987  4.249052  1989.0  2005.00
# Transit                        397.0  2011.236776  2.077867  2002.0  2010.00
# Transit Timing Variations        4.0  2012.500000  1.290994  2011.0  2011.75
#
#                                   50%      75%     max
# method
# ...

# %%
df.groupby('method').aggregate([min,max,sum,'mean','median'])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10932\564616263.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby('method').aggregate([min,max,sum,'mean','median'])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10932\564616263.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.groupby('method').aggregate([min,max,sum,'mean','median'])
# ...

# %% [markdown]
# # Filtering

# %%
df.groupby('method').std()
# Out:
#                                  number  orbital_period      mass  \
# method
# Astrometry                     0.000000      544.217663       NaN
# Eclipse Timing Variations      0.500000     2499.130945  1.308148
# Imaging                        0.933035   213978.177277       NaN
# Microlensing                   0.387553     1113.166333       NaN
# Orbital Brightness Modulation  0.577350        0.725493       NaN
# Pulsar Timing                  1.095445    16313.265573       NaN
# Pulsation Timing Variations         NaN             NaN       NaN
# Radial Velocity                1.157141     1454.926210  3.825883
# Transit                        1.399119       46.185893       NaN
# Transit Timing Variations      0.500000       71.599884       NaN
#
#                                   distance      year
# method
# Astrometry                        4.094148  2.121320
# Eclipse Timing Variations       213.203907  1.414214
# Imaging                          53.736817  2.781901
# ...

# %%
df.groupby('method').mean()
# Out:
#                                  number  orbital_period      mass  \
# method
# Astrometry                     1.000000      631.180000       NaN
# Eclipse Timing Variations      1.666667     4751.644444  5.125000
# Imaging                        1.315789   118247.737500       NaN
# Microlensing                   1.173913     3153.571429       NaN
# Orbital Brightness Modulation  1.666667        0.709307       NaN
# Pulsar Timing                  2.200000     7343.021201       NaN
# Pulsation Timing Variations    1.000000     1170.000000       NaN
# Radial Velocity                1.721519      823.354680  2.630699
# Transit                        1.954660       21.102073  1.470000
# Transit Timing Variations      2.250000       79.783500       NaN
#
#                                   distance         year
# method
# Astrometry                       17.875000  2011.500000
# Eclipse Timing Variations       315.360000  2010.000000
# ...

# %%
def testFunc(a):
    return a['distance'].mean()<1000

df.groupby('method').filter(testFunc)
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [999 rows x 6 columns]
